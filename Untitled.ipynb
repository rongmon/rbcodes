# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from rbcodes.GUIs.rb_spec import rb_spec as r
from rbcodes.IGM import rb_setline as setline
from linetools.spectra.xspectrum1d import XSpectrum1D  
from importlib import reload

# %%
filename='example-data/test.fits'
s=r.from_file(filename,filetype='linetools')
#Redshift of the absorber you are trying to fit
zabs=0.348
transition=977.6 # CIII 977 
s.shift_spec(zabs);

xlim=[-1500,1500]
s.slice_spec(transition,xlim[0],xlim[1],use_vel=True);
#s.fit_continuum(mask=[-1485,-1385,-200,200,160,360],domain=xlim,Legendre=True,optimize_cont=True)
s.fit_continuum(mask=[-700,-540,-80,50,135,360,462,670,780,980],domain=xlim,Legendre=True,
                optimize_cont=True,n_sigma=3.,use_weights=True)

_binsize= 3
s.compute_EW(transition,vmin=-80.,vmax=55.,plot=True,SNR=True,_binsize=_binsize);
# Out:
# Testing polynomial orders from 0 to 7...
# Order 0: BIC = 1.78, StdDev = 0.1893
# Order 1: BIC = -8.16, StdDev = 0.1837
# Order 2: BIC = -13.22, StdDev = 0.1816
# Order 3: BIC = -8.19, StdDev = 0.1817
# Order 4: BIC = -4.74, StdDev = 0.1814
# Order 5: BIC = 0.94, StdDev = 0.1815
# Order 6: BIC = 5.21, StdDev = 0.1813
# Order 7: BIC = 10.82, StdDev = 0.1812
#
# Optimal polynomial order: 2
# BIC value: -13.22
# Standard deviation of residuals: 0.1816
# Both statistical and continuum fitting error included.
# <img src="data:image/png;base64,..." width="1000">

# %%
from rbcodes.IGM import compute_EW as cew
reload(cew)
# Out:
# <module 'rbcodes.IGM.compute_EW' from '/Users/bordoloi/WORK/python/rbcodes/IGM/compute_EW.py'>

# %%
out=cew.compute_EW(s.wave_slice,s.fnorm,977.02,[-80,55],s.enorm,zabs=0,plot=True)
# Out:
# <img src="data:image/png;base64,..." width="1000">
